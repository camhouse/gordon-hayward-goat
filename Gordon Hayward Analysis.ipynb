# %% [markdown]
# ### Playing around with Gordon Hayward NBA data ###
# Purpose is to get more familiar with Jupyter and Python

# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import playergamelogs
career = playercareerstats.PlayerCareerStats(player_id='202330')
# Gordon Hayward, taken from nba.com
career.get_data_frames()[0]

# %%
gamelog = playergamelogs.PlayerGameLogs(player_id_nullable='202330')
log = gamelog.get_data_frames()[0]

# %%
log
# Out:
#    SEASON_YEAR  PLAYER_ID     PLAYER_NAME NICKNAME     TEAM_ID  \
# 0      2016-17     202330  Gordon Hayward   Gordon  1610612762
# 1      2016-17     202330  Gordon Hayward   Gordon  1610612762
# 2      2016-17     202330  Gordon Hayward   Gordon  1610612762
# 3      2016-17     202330  Gordon Hayward   Gordon  1610612762
# 4      2016-17     202330  Gordon Hayward   Gordon  1610612762
# ..         ...        ...             ...      ...         ...
# 68     2016-17     202330  Gordon Hayward   Gordon  1610612762
# 69     2016-17     202330  Gordon Hayward   Gordon  1610612762
# 70     2016-17     202330  Gordon Hayward   Gordon  1610612762
# 71     2016-17     202330  Gordon Hayward   Gordon  1610612762
# 72     2016-17     202330  Gordon Hayward   Gordon  1610612762
#
#    TEAM_ABBREVIATION  TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP  \
# 0                UTA  Utah Jazz  0021601227  2017-04-12T00:00:00  UTA vs. SAS
# ...
